# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import sklearn
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras

print (tf.__version__)
print (sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print (module.__name__, module.__version__)
# Out:
# 2.0.0-beta1
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# matplotlib 3.1.1
# numpy 1.16.4
# pandas 0.24.2
# sklearn 0.21.2
# tensorflow 2.0.0-beta1
# tensorflow.python.keras.api._v2.keras 2.2.4-tf

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
print (housing.DESCR)
print (housing.data.shape)
print (housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
import pprint
pprint.pprint (housing.data[0:5])
pprint.pprint(housing.target[0:5])
# Out:
# array([[ 8.32520000e+00,  4.10000000e+01,  6.98412698e+00,
#          1.02380952e+00,  3.22000000e+02,  2.55555556e+00,
#          3.78800000e+01, -1.22230000e+02],
#        [ 8.30140000e+00,  2.10000000e+01,  6.23813708e+00,
#          9.71880492e-01,  2.40100000e+03,  2.10984183e+00,
#          3.78600000e+01, -1.22220000e+02],
#        [ 7.25740000e+00,  5.20000000e+01,  8.28813559e+00,
#          1.07344633e+00,  4.96000000e+02,  2.80225989e+00,
#          3.78500000e+01, -1.22240000e+02],
#        [ 5.64310000e+00,  5.20000000e+01,  5.81735160e+00,
#          1.07305936e+00,  5.58000000e+02,  2.54794521e+00,
#          3.78500000e+01, -1.22250000e+02],
#        [ 3.84620000e+00,  5.20000000e+01,  6.28185328e+00,
#          1.08108108e+00,  5.65000000e+02,  2.18146718e+00,
#          3.78500000e+01, -1.22250000e+02]])
# array([4.526, 3.585, 3.521, 3.413, 3.422])

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    housing.data, housing.target, random_state = 7, test_size=0.25)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state=11, test_size = 0.25)

print (x_train.shape, y_train.shape)
print (x_valid.shape, y_valid.shape)
print (x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)  #这里使用fit_transform函数，因为在训练集上获得均值和方差，在验证集和测试集上面使用
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
learning_rate = [1e-4,3e-4,1e-3,3e-3,1e-2]
historys=[]

for lr in learning_rate:
    model = keras.models.Sequential([
        keras.layers.Dense(30, activation ='relu',
                          input_shape =x_train.shape[1:]),
        keras.layers.Dense(1),
    ])
    optimizer = keras.optimizers.SGD(lr)
    model.compile(loss="mean_squared_error", optimizer='sgd')
    callbacks = [keras.callbacks.EarlyStopping(
        patience=5, min_delta=1e-3)]
    history = model.fit(x_train_scaled,y_train,
                   validation_data=(x_valid_scaled,y_valid),
                   epochs=100,
                   callbacks=callbacks)
    historys.append(history)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 51us/sample - loss: 0.9837 - val_loss: 0.6019
# Epoch 2/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.4965 - val_loss: 0.4982
# Epoch 3/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.4580 - val_loss: 0.4605
# Epoch 4/100
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.4276 - val_loss: 0.4388
# Epoch 5/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.4200 - val_loss: 0.4515
# Epoch 6/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.4074 - val_loss: 0.4727
# Epoch 7/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.4345 - val_loss: 0.4136
# Epoch 8/100
# 11610/11610 [==============================] - 1s 49us/sample - loss: 0.4037 - val_loss: 0.4093
# Epoch 9/100
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.3913 - val_loss: 0.4027
# Epoch 10/100
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.3884 - val_loss: 0.4062
# Epoch 11/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3839 - val_loss: 0.3938
# Epoch 12/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.3762 - val_loss: 0.3890
# Epoch 13/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3802 - val_loss: 0.3936
# Epoch 14/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3720 - val_loss: 0.3927
# Epoch 15/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3691 - val_loss: 0.3817
# Epoch 16/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3738 - val_loss: 0.3901
# Epoch 17/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3667 - val_loss: 0.3862
# Epoch 18/100
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.3643 - val_loss: 0.3785
# Epoch 19/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3630 - val_loss: 0.3828
# Epoch 20/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.3642 - val_loss: 0.3712
# Epoch 21/100
# 11610/11610 [==============================] - 1s 53us/sample - loss: 0.3596 - val_loss: 0.3778
# Epoch 22/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3576 - val_loss: 0.3733
# Epoch 23/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3567 - val_loss: 0.3710
# Epoch 24/100
# 11610/11610 [==============================] - 1s 56us/sample - loss: 0.3545 - val_loss: 0.3680
# Epoch 25/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.3536 - val_loss: 0.3782
# Epoch 26/100
# 11610/11610 [==============================] - 1s 49us/sample - loss: 0.3566 - val_loss: 0.3690
# Epoch 27/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.3531 - val_loss: 0.3606
# Epoch 28/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3506 - val_loss: 0.3602
# Epoch 29/100
# 11610/11610 [==============================] - 1s 47us/sample - loss: 0.3502 - val_loss: 0.3585
# Epoch 30/100
# 11610/11610 [==============================] - 1s 48us/sample - loss: 0.3502 - val_loss: 0.3619
# Epoch 31/100
# 11610/11610 [==============================] - 1s 45us/sample - loss: 0.3487 - val_loss: 0.3589
# Epoch 32/100
# 11610/11610 [==============================] - 1s 51us/sample - loss: 0.3507 - val_loss: 0.3554
# Epoch 33/100
# 11610/11610 [==============================] - 1s 50us/sample - loss: 0.3520 - val_loss: 0.3836
# Epoch 34/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.3471 - val_loss: 0.3579
# Epoch 35/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.3479 - val_loss: 0.3711
# Epoch 36/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.3481 - val_loss: 0.3558
# Epoch 37/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3463 - val_loss: 0.3549
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 48us/sample - loss: 1.1595 - val_loss: 0.6247
# Epoch 2/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.5109 - val_loss: 0.4989
# Epoch 3/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.4607 - val_loss: 0.5186
# Epoch 4/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.4366 - val_loss: 0.4427
# Epoch 5/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.4113 - val_loss: 0.4225
# Epoch 6/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.4015 - val_loss: 0.4179
# Epoch 7/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.3949 - val_loss: 0.4089
# Epoch 8/100
# 11610/11610 [==============================] - 1s 49us/sample - loss: 0.3880 - val_loss: 0.4003
# Epoch 9/100
# 11610/11610 [==============================] - 1s 47us/sample - loss: 0.3828 - val_loss: 0.3979
# Epoch 10/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.3792 - val_loss: 0.4039
# Epoch 11/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3776 - val_loss: 0.3932
# Epoch 12/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3734 - val_loss: 0.3879
# Epoch 13/100
# 11610/11610 [==============================] - 1s 48us/sample - loss: 0.3695 - val_loss: 0.3848
# Epoch 14/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.3675 - val_loss: 0.3825
# Epoch 15/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.3660 - val_loss: 0.3868
# Epoch 16/100
# 11610/11610 [==============================] - 1s 49us/sample - loss: 0.3633 - val_loss: 0.3824
# Epoch 17/100
# 11610/11610 [==============================] - 1s 47us/sample - loss: 0.3612 - val_loss: 0.3738
# Epoch 18/100
# 11610/11610 [==============================] - 1s 49us/sample - loss: 0.3611 - val_loss: 0.3729
# Epoch 19/100
# 11610/11610 [==============================] - 1s 50us/sample - loss: 0.3589 - val_loss: 0.3742
# Epoch 20/100
# 11610/11610 [==============================] - 1s 50us/sample - loss: 0.3586 - val_loss: 0.3724
# Epoch 21/100
# 11610/11610 [==============================] - 1s 48us/sample - loss: 0.3550 - val_loss: 0.3680
# Epoch 22/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 0.3543 - val_loss: 0.3701
# Epoch 23/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.3535 - val_loss: 0.3641
# Epoch 24/100
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.3525 - val_loss: 0.3642
# Epoch 25/100
# 11610/11610 [==============================] - 1s 48us/sample - loss: 0.3501 - val_loss: 0.3665
# Epoch 26/100
# 11610/11610 [==============================] - 1s 50us/sample - loss: 0.3496 - val_loss: 0.3636
# Epoch 27/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.3476 - val_loss: 0.3633
# Epoch 28/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3459 - val_loss: 0.3582
# Epoch 29/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3466 - val_loss: 0.3573
# Epoch 30/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.3477 - val_loss: 0.3542
# Epoch 31/100
# 11610/11610 [==============================] - 1s 45us/sample - loss: 0.3447 - val_loss: 0.3591
# Epoch 32/100
# 11610/11610 [==============================] - 1s 52us/sample - loss: 0.3422 - val_loss: 0.3537
# Epoch 33/100
# 11610/11610 [==============================] - 1s 52us/sample - loss: 0.3450 - val_loss: 0.3504
# Epoch 34/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 0.3489 - val_loss: 0.3529
# Epoch 35/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3405 - val_loss: 0.3496
# Epoch 36/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3400 - val_loss: 0.3493
# Epoch 37/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3387 - val_loss: 0.3505
# Epoch 38/100
# 11610/11610 [==============================] - 1s 50us/sample - loss: 0.3392 - val_loss: 0.3472
# Epoch 39/100
# 11610/11610 [==============================] - 1s 83us/sample - loss: 0.3402 - val_loss: 0.3467
# Epoch 40/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3374 - val_loss: 0.3503
# Epoch 41/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.3340 - val_loss: 0.3443
# Epoch 42/100
# 11610/11610 [==============================] - 1s 126us/sample - loss: 0.3340 - val_loss: 0.6547
# Epoch 43/100
# 11610/11610 [==============================] - 1s 53us/sample - loss: 0.3409 - val_loss: 0.3443
# Epoch 44/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.3326 - val_loss: 0.3433
# Epoch 45/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.3335 - val_loss: 0.3418
# Epoch 46/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.3340 - val_loss: 0.3445
# Epoch 47/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3314 - val_loss: 0.3386
# Epoch 48/100
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.3284 - val_loss: 0.3423
# Epoch 49/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.3288 - val_loss: 0.3413
# Epoch 50/100
# 11610/11610 [==============================] - 1s 48us/sample - loss: 0.3296 - val_loss: 0.3371
# Epoch 51/100
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.3304 - val_loss: 0.3439
# Epoch 52/100
# 11610/11610 [==============================] - 1s 49us/sample - loss: 0.3279 - val_loss: 0.3374
# Epoch 53/100
# 11610/11610 [==============================] - 1s 53us/sample - loss: 0.3304 - val_loss: 0.3369
# Epoch 54/100
# 11610/11610 [==============================] - 1s 53us/sample - loss: 0.3263 - val_loss: 0.3368
# Epoch 55/100
# 11610/11610 [==============================] - 1s 51us/sample - loss: 0.3265 - val_loss: 0.3376
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.7757 - val_loss: 0.5845
# Epoch 2/100
# 11610/11610 [==============================] - 1s 113us/sample - loss: 0.8012 - val_loss: 0.5175
# Epoch 3/100
# 11610/11610 [==============================] - 2s 170us/sample - loss: 0.4672 - val_loss: 0.4582
# Epoch 4/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4293 - val_loss: 0.4376
# Epoch 5/100
# 11610/11610 [==============================] - 1s 123us/sample - loss: 0.4095 - val_loss: 0.5957
# Epoch 6/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.4037 - val_loss: 0.4073
# Epoch 7/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3904 - val_loss: 0.4052
# Epoch 8/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.3828 - val_loss: 0.3979
# Epoch 9/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.3777 - val_loss: 0.3869
# Epoch 10/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.3810 - val_loss: 0.3809
# Epoch 11/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3723 - val_loss: 0.4080
# Epoch 12/100
# 11610/11610 [==============================] - 1s 106us/sample - loss: 0.3710 - val_loss: 0.3829
# Epoch 13/100
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.3659 - val_loss: 0.3757
# Epoch 14/100
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.3627 - val_loss: 0.3755
# Epoch 15/100
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3881 - val_loss: 0.3770
# Epoch 16/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3670 - val_loss: 0.3712
# Epoch 17/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.3561 - val_loss: 0.3627
# Epoch 18/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.3531 - val_loss: 0.3603
# Epoch 19/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3522 - val_loss: 0.3615
# Epoch 20/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.3496 - val_loss: 0.3841
# Epoch 21/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.3489 - val_loss: 0.3560
# Epoch 22/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.3635 - val_loss: 0.3535
# Epoch 23/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3479 - val_loss: 0.3541
# Epoch 24/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3447 - val_loss: 0.3529
# Epoch 25/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3429 - val_loss: 0.3517
# Epoch 26/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3473 - val_loss: 0.3536
# Epoch 27/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.3440 - val_loss: 0.3483
# Epoch 28/100
# 11610/11610 [==============================] - 1s 110us/sample - loss: 0.3392 - val_loss: 0.3560
# Epoch 29/100
# 11610/11610 [==============================] - 1s 128us/sample - loss: 0.3438 - val_loss: 0.3502
# Epoch 30/100
# 11610/11610 [==============================] - 1s 124us/sample - loss: 0.3379 - val_loss: 0.3477
# Epoch 31/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3375 - val_loss: 0.3470
# Epoch 32/100
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.3385 - val_loss: 0.3478
# Epoch 33/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 0.3358 - val_loss: 0.3420
# Epoch 34/100
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.3348 - val_loss: 0.3464
# Epoch 35/100
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.3344 - val_loss: 0.3422
# Epoch 36/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.3354 - val_loss: 0.3430
# Epoch 37/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3357 - val_loss: 0.3457
# Epoch 38/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3322 - val_loss: 0.3429
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 1.0625 - val_loss: 0.5428
# Epoch 2/100
# 11610/11610 [==============================] - 1s 47us/sample - loss: 0.4640 - val_loss: 0.4560
# Epoch 3/100
# 11610/11610 [==============================] - 1s 51us/sample - loss: 0.4244 - val_loss: 0.4376
# Epoch 4/100
# 11610/11610 [==============================] - 1s 51us/sample - loss: 0.4039 - val_loss: 0.4143
# Epoch 5/100
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.3930 - val_loss: 0.4052
# Epoch 6/100
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.3845 - val_loss: 0.3940
# Epoch 7/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.3801 - val_loss: 0.3917
# Epoch 8/100
# 11610/11610 [==============================] - 1s 123us/sample - loss: 0.3777 - val_loss: 0.3914
# Epoch 9/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.3742 - val_loss: 0.3843
# Epoch 10/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3720 - val_loss: 0.3802
# Epoch 11/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3700 - val_loss: 0.3807
# Epoch 12/100
# 11610/11610 [==============================] - 1s 56us/sample - loss: 0.3688 - val_loss: 0.3752
# Epoch 13/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3676 - val_loss: 0.4110
# Epoch 14/100
# 11610/11610 [==============================] - 1s 56us/sample - loss: 0.3672 - val_loss: 0.3729
# Epoch 15/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.3638 - val_loss: 0.3778
# Epoch 16/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3656 - val_loss: 0.3727
# Epoch 17/100
# 11610/11610 [==============================] - 1s 56us/sample - loss: 0.3593 - val_loss: 0.3682
# Epoch 18/100
# 11610/11610 [==============================] - 1s 53us/sample - loss: 0.3574 - val_loss: 0.3664
# Epoch 19/100
# 11610/11610 [==============================] - 1s 52us/sample - loss: 0.3631 - val_loss: 0.3650
# Epoch 20/100
# 11610/11610 [==============================] - 1s 52us/sample - loss: 0.3571 - val_loss: 0.3689
# Epoch 21/100
# 11610/11610 [==============================] - 1s 50us/sample - loss: 0.3541 - val_loss: 0.3638
# Epoch 22/100
# 11610/11610 [==============================] - 1s 56us/sample - loss: 0.3527 - val_loss: 0.3636
# Epoch 23/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3542 - val_loss: 0.3710
# Epoch 24/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.3497 - val_loss: 0.3646
# Epoch 25/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.3486 - val_loss: 0.3804
# Epoch 26/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3484 - val_loss: 0.3636
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 2.6631 - val_loss: 0.6091
# Epoch 2/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4959 - val_loss: 0.4690
# Epoch 3/100
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.4552 - val_loss: 0.4423
# Epoch 4/100
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.4184 - val_loss: 0.4213
# Epoch 5/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3974 - val_loss: 0.4083
# Epoch 6/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3898 - val_loss: 0.4060
# Epoch 7/100
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.3873 - val_loss: 0.4061
# Epoch 8/100
# 11610/11610 [==============================] - 1s 57us/sample - loss: 0.3804 - val_loss: 0.3934
# Epoch 9/100
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3736 - val_loss: 0.3836
# Epoch 10/100
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3714 - val_loss: 0.3832
# Epoch 11/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 0.3659 - val_loss: 0.3984
# Epoch 12/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 0.3683 - val_loss: 0.3818
# Epoch 13/100
# 11610/11610 [==============================] - 1s 58us/sample - loss: 0.3611 - val_loss: 0.3726
# Epoch 14/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.3585 - val_loss: 0.3711
# Epoch 15/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.3594 - val_loss: 0.3684
# Epoch 16/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3579 - val_loss: 0.3671
# Epoch 17/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.3612 - val_loss: 0.3723
# Epoch 18/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3532 - val_loss: 0.3652
# Epoch 19/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.3519 - val_loss: 0.3673
# Epoch 20/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.3528 - val_loss: 0.3623
# Epoch 21/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3485 - val_loss: 0.3667
# Epoch 22/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3465 - val_loss: 0.3618
# Epoch 23/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 0.3480 - val_loss: 0.3791
# Epoch 24/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3507 - val_loss: 0.3583
# Epoch 25/100
# 11610/11610 [==============================] - 1s 56us/sample - loss: 0.3491 - val_loss: 0.3597
# Epoch 26/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.3483 - val_loss: 0.3902
# Epoch 27/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3454 - val_loss: 0.3766
# Epoch 28/100
# 11610/11610 [==============================] - 1s 55us/sample - loss: 0.3448 - val_loss: 0.3645
# Epoch 29/100
# 11610/11610 [==============================] - 1s 52us/sample - loss: 0.3829 - val_loss: 0.3772

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)

    plt.show()
for lr,history  in zip(learning_rate,historys):
    print (lr)
    plot_learning_curves(history)
# Out:
# 0.0001
# 0.0003
# 0.001
# 0.003
# 0.01
